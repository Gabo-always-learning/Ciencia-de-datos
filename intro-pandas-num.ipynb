# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabo-always-learning/Ciencia-de-datos/blob/main/intro-pandas-num.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/mcd-unison/material-programacion/blob/main/intro-pandas-num.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <p><img src="https://mcd.unison.mx/wp-content/themes/awaken/img/logo_mcd.png" width="100">
# </p>
#
#
# # Curso Propedéutico en *Programación*
#
# # Uso de pandas en datos numéricos y temporales
#
#
# **Julio Waissman Vilanova**
# </center>

# %%
import pandas as pd

# %% [markdown]
# ## Leyendo y revisando los datos
#
# Para ejemplificar el uso de columnas numéricas, horas y fechas vamos a utilizar un conjunto de datos que puso generosamente a nuestra disposición [Hector Alberto Gutierrez Ibarra](hector.gutierrez@cenace.gob.mx) de la gerencia noroeste del *Centro Nacional de Control de Energía (CENACE)*.
#
# Vamos primero pegandole un ojo a los datos:

# %%
path_datos = "https://github.com/juliowaissman/curso-python-cd/raw/main/datos/caso_zc_hmo.csv.zip"
df = pd.read_csv(path_datos)
df
# Out:
#                    Date   Demand  Temperature  PrecipIntensity  Humidity  \
# 0      02/01/2016 00:00  225.622          7.3              0.0      49.0
# 1      02/01/2016 01:00  213.620          6.6              0.0      54.0
# 2      02/01/2016 02:00  207.360          5.8              0.0      60.0
# 3      02/01/2016 03:00  201.374          5.0              0.0      67.0
# 4      02/01/2016 04:00  199.018          4.4              0.0      69.0
# ...                 ...      ...          ...              ...       ...
# 48158  30/06/2021 19:00  911.216         27.4              0.0      77.0
# 48159  30/06/2021 20:00  833.093         27.8              0.0      74.2
# 48160  30/06/2021 21:00  791.669         28.2              0.0      74.0
# 48161  30/06/2021 22:00  783.028         28.2              0.0      73.5
# 48162  30/06/2021 23:00  789.379         28.0              0.0      75.5
#
#        WindSpeed
# 0            3.2
# 1            4.0
# 2            5.2
# 3            5.6
# 4            6.0
# ...          ...
# 48158        4.0
# 48159        2.4
# 48160        4.0
# 48161        2.8
# 48162        1.6
#
# [48163 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48163 entries, 0 to 48162
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             48163 non-null  object
#  1   Demand           48163 non-null  float64
#  2   Temperature      48163 non-null  float64
#  3   PrecipIntensity  48163 non-null  float64
#  4   Humidity         48163 non-null  float64
#  5   WindSpeed        48163 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# Lo primero que tenemos que hacer es convertir la variable `Date`en un formato de fechas. En este caso es muy fácil porque la tabla está muy bien formateada, pero suele no ser tan sencillo.

# %%
df['Date'] = pd.to_datetime(df.Date, format="%d/%m/%Y %H:%M")

df
# Out:
#                      Date   Demand  Temperature  PrecipIntensity  Humidity  \
# 0     2016-01-02 00:00:00  225.622          7.3              0.0      49.0
# 1     2016-01-02 01:00:00  213.620          6.6              0.0      54.0
# 2     2016-01-02 02:00:00  207.360          5.8              0.0      60.0
# 3     2016-01-02 03:00:00  201.374          5.0              0.0      67.0
# 4     2016-01-02 04:00:00  199.018          4.4              0.0      69.0
# ...                   ...      ...          ...              ...       ...
# 48158 2021-06-30 19:00:00  911.216         27.4              0.0      77.0
# 48159 2021-06-30 20:00:00  833.093         27.8              0.0      74.2
# 48160 2021-06-30 21:00:00  791.669         28.2              0.0      74.0
# 48161 2021-06-30 22:00:00  783.028         28.2              0.0      73.5
# 48162 2021-06-30 23:00:00  789.379         28.0              0.0      75.5
#
#        WindSpeed
# 0            3.2
# 1            4.0
# 2            5.2
# 3            5.6
# 4            6.0
# ...          ...
# 48158        4.0
# 48159        2.4
# 48160        4.0
# 48161        2.8
# 48162        1.6
#
# [48163 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48163 entries, 0 to 48162
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             48163 non-null  datetime64[ns]
#  1   Demand           48163 non-null  float64
#  2   Temperature      48163 non-null  float64
#  3   PrecipIntensity  48163 non-null  float64
#  4   Humidity         48163 non-null  float64
#  5   WindSpeed        48163 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 2.2 MB

# %%
df.describe()
# Out:
#                                 Date        Demand   Temperature  \
# count                          48163  48163.000000  48163.000000
# mean   2018-10-01 11:56:59.861719552    525.771983     21.636258
# min              2016-01-02 00:00:00    184.406000     -6.700000
# 25%              2017-05-17 18:30:00    338.250000     15.000000
# 50%              2018-10-01 12:00:00    467.568000     21.700000
# 75%              2020-02-15 05:30:00    693.551500     28.500000
# max              2021-06-30 23:00:00   1234.047000     46.400000
# std                              NaN    220.405604      9.296498
#
#        PrecipIntensity      Humidity     WindSpeed
# count     48163.000000  48163.000000  48163.000000
# mean          0.044212     40.864779      4.759419
# min           0.000000      0.130000      0.000000
# 25%           0.000000     22.000000      2.800000
# 50%           0.000000     37.000000      4.400000
# 75%           0.000000     57.000000      6.400000
# max          19.800000    100.000000     35.000000
# std           0.391912     23.530212      2.640389

# %% [markdown]
# ¿Cuantos días tenemos en esta base? ¿Cual es el primer día y el último?

# %%
print(f"Inicia el {df.Date.min()} y termina el {df.Date.max()}")
print(f"Con una duración de {df.Date.max() - df.Date.min()}")
# Out:
# Inicia el 2016-01-02 00:00:00 y termina el 2021-06-30 23:00:00
# Con una duración de 2006 days 23:00:00

# %% [markdown]
# Hay que tener cuidado porque hay dos tipos fundamentales de formatos de tiempo, y suelen no mesclarse bien en algunas operaciones.

# %%
type(df.Date.min()), type(df.Date.max() - df.Date.min())
# Out:
# (pandas._libs.tslibs.timestamps.Timestamp,
#  pandas._libs.tslibs.timedeltas.Timedelta)

# %% [markdown]
# Para facilitar el uso de pandas, vamos a pasar la fecha como el indice del dataframe

# %%
# df.index = df.Date
# df.drop(columns='Date', inplace=True)
df.set_index('Date', inplace=True)
df
# Out:
#                       Demand  Temperature  PrecipIntensity  Humidity  \
# Date
# 2016-01-02 00:00:00  225.622          7.3              0.0      49.0
# 2016-01-02 01:00:00  213.620          6.6              0.0      54.0
# 2016-01-02 02:00:00  207.360          5.8              0.0      60.0
# 2016-01-02 03:00:00  201.374          5.0              0.0      67.0
# 2016-01-02 04:00:00  199.018          4.4              0.0      69.0
# ...                      ...          ...              ...       ...
# 2021-06-30 19:00:00  911.216         27.4              0.0      77.0
# 2021-06-30 20:00:00  833.093         27.8              0.0      74.2
# 2021-06-30 21:00:00  791.669         28.2              0.0      74.0
# 2021-06-30 22:00:00  783.028         28.2              0.0      73.5
# 2021-06-30 23:00:00  789.379         28.0              0.0      75.5
#
#                      WindSpeed
# Date
# 2016-01-02 00:00:00        3.2
# 2016-01-02 01:00:00        4.0
# 2016-01-02 02:00:00        5.2
# 2016-01-02 03:00:00        5.6
# 2016-01-02 04:00:00        6.0
# ...                        ...
# 2021-06-30 19:00:00        4.0
# 2021-06-30 20:00:00        2.4
# 2021-06-30 21:00:00        4.0
# 2021-06-30 22:00:00        2.8
# 2021-06-30 23:00:00        1.6
#
# [48163 rows x 5 columns]

# %%
df['2021-05':'2021-05']
# Out:
#                       Demand  Temperature  PrecipIntensity  Humidity  \
# Date
# 2021-05-01 00:00:00  553.348         27.0              0.0      22.2
# 2021-05-01 01:00:00  549.269         23.2              0.0      26.8
# 2021-05-01 02:00:00  522.898         22.4              0.0      28.0
# 2021-05-01 03:00:00  497.035         22.4              0.0      27.5
# 2021-05-01 04:00:00  475.905         22.8              0.0      27.0
# ...                      ...          ...              ...       ...
# 2021-05-31 19:00:00  895.189         31.8              0.0      33.5
# 2021-05-31 20:00:00  840.256         30.4              0.0      32.5
# 2021-05-31 21:00:00  786.508         29.1              0.0      37.2
# 2021-05-31 22:00:00  775.294         28.2              0.0      39.5
# 2021-05-31 23:00:00  770.170         27.3              0.0      40.8
#
#                      WindSpeed
# Date
# 2021-05-01 00:00:00        2.8
# 2021-05-01 01:00:00        3.2
# 2021-05-01 02:00:00        3.2
# 2021-05-01 03:00:00        3.6
# 2021-05-01 04:00:00        4.0
# ...                        ...
# 2021-05-31 19:00:00        5.6
# 2021-05-31 20:00:00        3.2
# 2021-05-31 21:00:00        3.2
# 2021-05-31 22:00:00        1.6
# 2021-05-31 23:00:00        0.0
#
# [744 rows x 5 columns]

# %% [markdown]
# ## Gráficas rápidas y furiosas desde pandas
#
# Pandas trae incluidas facilidades para la graficación con el fin de hacer análisis rápidos de nuestras variables, así que vamos aprovechando y haciendo una inspección visual

# %%
ax = df.Demand.plot()

# %%
ax = df.plot(figsize=(12, 20), subplots=True)

# %%
ax = df.Temperature.plot.box()

# %%
ax = df.plot.scatter(
    x='Humidity',
    y='Temperature',
    c='Demand',
    s =40,
    figsize=(12,8)
)

# %% [markdown]
# # Generando nuevas variables a partir de las variables conocidas
#
# Generar nuevas variables es relativamente simple, pero hay algunas cosas que son diferentes con numpy y por las cuales hay que tener cuidado.

# %%
df['farenheit'] = (df.Temperature * 9/5) + 32

# %%
df['refri'] = 0
df['refri'] = df.refri.where(df.Temperature < 38, 1)
df.describe()
# Out:
#              Demand   Temperature  PrecipIntensity      Humidity  \
# count  48163.000000  48163.000000     48163.000000  48163.000000
# mean     525.771983     21.636258         0.044212     40.864779
# std      220.405604      9.296498         0.391912     23.530212
# min      184.406000     -6.700000         0.000000      0.130000
# 25%      338.250000     15.000000         0.000000     22.000000
# 50%      467.568000     21.700000         0.000000     37.000000
# 75%      693.551500     28.500000         0.000000     57.000000
# max     1234.047000     46.400000        19.800000    100.000000
#
#           WindSpeed     farenheit         refri
# count  48163.000000  48163.000000  48163.000000
# mean       4.759419     70.945265      0.034840
# std        2.640389     16.733696      0.183376
# min        0.000000     19.940000      0.000000
# 25%        2.800000     59.000000      0.000000
# 50%        4.400000     71.060000      0.000000
# 75%        6.400000     83.300000      0.000000
# max       35.000000    115.520000      1.000000

# %%
df['DiaSemana'] = df.index.day_of_week
df
# Out:
#                       Demand  Temperature  PrecipIntensity  Humidity  \
# Date
# 2016-01-02 00:00:00  225.622          7.3              0.0      49.0
# 2016-01-02 01:00:00  213.620          6.6              0.0      54.0
# 2016-01-02 02:00:00  207.360          5.8              0.0      60.0
# 2016-01-02 03:00:00  201.374          5.0              0.0      67.0
# 2016-01-02 04:00:00  199.018          4.4              0.0      69.0
# ...                      ...          ...              ...       ...
# 2021-06-30 19:00:00  911.216         27.4              0.0      77.0
# 2021-06-30 20:00:00  833.093         27.8              0.0      74.2
# 2021-06-30 21:00:00  791.669         28.2              0.0      74.0
# 2021-06-30 22:00:00  783.028         28.2              0.0      73.5
# 2021-06-30 23:00:00  789.379         28.0              0.0      75.5
#
#                      WindSpeed  farenheit  refri  DiaSemana
# Date
# 2016-01-02 00:00:00        3.2      45.14      0          5
# 2016-01-02 01:00:00        4.0      43.88      0          5
# 2016-01-02 02:00:00        5.2      42.44      0          5
# 2016-01-02 03:00:00        5.6      41.00      0          5
# 2016-01-02 04:00:00        6.0      39.92      0          5
# ...                        ...        ...    ...        ...
# 2021-06-30 19:00:00        4.0      81.32      0          2
# 2021-06-30 20:00:00        2.4      82.04      0          2
# 2021-06-30 21:00:00        4.0      82.76      0          2
# 2021-06-30 22:00:00        2.8      82.76      0          2
# 2021-06-30 23:00:00        1.6      82.40      0          2
#
# [48163 rows x 8 columns]

# %%
df.rename(
    columns={
        'Demand': 'Demanda',
        'Temperature': 'Temperatura',
        'PrecipIntensity': 'Precipitación',
        'Humidity': 'Humedad',
        'WinSpeed': 'VelocidadViento',
    },
    inplace=True
)
df
# Out:
#                      Demanda  Temperatura  Precipitación  Humedad  WindSpeed  \
# Date
# 2016-01-02 00:00:00  225.622          7.3            0.0     49.0        3.2
# 2016-01-02 01:00:00  213.620          6.6            0.0     54.0        4.0
# 2016-01-02 02:00:00  207.360          5.8            0.0     60.0        5.2
# 2016-01-02 03:00:00  201.374          5.0            0.0     67.0        5.6
# 2016-01-02 04:00:00  199.018          4.4            0.0     69.0        6.0
# ...                      ...          ...            ...      ...        ...
# 2021-06-30 19:00:00  911.216         27.4            0.0     77.0        4.0
# 2021-06-30 20:00:00  833.093         27.8            0.0     74.2        2.4
# 2021-06-30 21:00:00  791.669         28.2            0.0     74.0        4.0
# 2021-06-30 22:00:00  783.028         28.2            0.0     73.5        2.8
# 2021-06-30 23:00:00  789.379         28.0            0.0     75.5        1.6
#
#                      farenheit  refri  DiaSemana
# Date
# 2016-01-02 00:00:00      45.14      0          5
# 2016-01-02 01:00:00      43.88      0          5
# 2016-01-02 02:00:00      42.44      0          5
# 2016-01-02 03:00:00      41.00      0          5
# 2016-01-02 04:00:00      39.92      0          5
# ...                        ...    ...        ...
# 2021-06-30 19:00:00      81.32      0          2
# 2021-06-30 20:00:00      82.04      0          2
# 2021-06-30 21:00:00      82.76      0          2
# 2021-06-30 22:00:00      82.76      0          2
# 2021-06-30 23:00:00      82.40      0          2
#
# [48163 rows x 8 columns]

# %% [markdown]
# ## Analizando con regrupamientos
#
# En particular, es interesante poder hacer algun análisis exploratorio utilizando las facilidades que da el uso del manejo de la información temporal que ofrece pandas. En espacial cuando se combina con `groupby` y diferentes funciones de agregación.
#
# Vamos a empezar por ver la demanda promedio por día de la semana:

# %%
ax = (df.
      groupby(df.index.month)[['Demanda']]
      .boxplot(subplots=False, rot=90))

# %%
df.boxplot(column ='Demanda', by='Month')
# Out:
# <Axes: title={'center': 'Demanda'}, xlabel='Month'>

# %%
df_semana = df.groupby('DiaSemana').agg(
    {
        'Demanda': ['min', 'max', 'mean', 'median', 'std'],
        'Precipitación': ['min', 'max']
    }
)
df_semana
# Out:
#            Demanda                                             Precipitación  \
#                min       max        mean    median         std           min
# DiaSemana
# 0          192.158  1196.584  526.063869  467.0655  227.427563           0.0
# 1          196.605  1207.485  541.060945  481.1390  224.332844           0.0
# 2          204.323  1219.607  542.040275  481.9890  222.707674           0.0
# 3          184.406  1234.047  543.177188  480.7525  223.888455           0.0
# 4          217.592  1217.896  539.779390  480.2355  221.994448           0.0
# 5          198.430  1141.884  512.861563  457.8225  210.097151           0.0
# 6          192.203  1081.747  475.493604  418.7660  203.003469           0.0
#
#
#             max
# DiaSemana
# 0           8.8
# 1          10.1
# 2          19.8
# 3           9.6
# 4          11.3
# 5          13.6
# 6          16.3

# %% [markdown]
# Ahora vamos a ver que pasa en forma mensual

# %%
ax = df[['Demanda']].groupby(df.index.month).boxplot(subplots=False, rot=90, figsize=(12, 7))

# %%
ax = df[['Temperatura']].groupby(df.index.month).boxplot(subplots=False, rot=90, figsize=(12, 7))

# %% [markdown]
# O inclusive por hora del día

# %%
ax = df[['Demanda']].groupby(df.index.hour).boxplot(subplots=False, rot=90, figsize=(12, 7))

# %%
df_hora = df[['Demanda', 'Temperatura']].groupby([df.index.hour, df.index.month]).mean().unstack()
df_hora
# Out:
#          Demanda                                                              \
# Date          1           2           3           4           5           6
# Date
# 0     284.280784  298.630971  337.861312  448.732089  592.498430  808.371839
# 1     269.599281  282.629900  319.658581  431.580211  574.092575  788.809772
# 2     260.116551  271.886818  306.967430  413.064709  542.380753  749.662456
# 3     253.609865  265.007076  297.823290  391.835067  513.308108  713.314622
